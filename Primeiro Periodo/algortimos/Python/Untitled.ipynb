# %%
import pandas as pd

# %%
def linha(tam=104):
    return '-'*tam

def cabeçalho (txt):
    print (linha())
    print (txt.center(104))
    print (linha())

    
def menu(lista):
    cabeçalho('MENU')
    c=1
    for item in lista:
        print(f'{c}-{item}')
        c +=1
    print (linha())
    
    
#resultado
menu (['Categorias', 'Reservas', 'Registro dos alunos', 'Entregas','Cadastrar livro', 'Sair'])


opcao = int(input("Opção:"))

if opcao ==  1:
    def categorias(lista):
        cabeçalho('CATEGORIAS')
        c=1
        for item in lista:
            print(f'{c}-{item}')
            c +=1
        print (linha())
    categorias (['Matemática', 'Física', 'Filosofia', 'Suspense', 'Romance'])
    categoria = int(input("Qual é a categoria desejada?:"))
    
    if categoria == 1:
        matematica_df = pd.read_excel ("livrosMatematica.xlsx")
        display (matematica_df)        
        #z = input("Nome do livro:") 
        #matematica_df[matematica_df["Título"].str.contains(pat=z,case=False)]      ESSA PARTE NAO PEGA :/ 
        
    elif categoria == 2:
        fisica_df = pd.read_excel ("livrosFisica.xlsx")
        display (fisica_df)
        
    elif categoria == 3:
        filosofAutoria_df = pd.read_excel ("livrosFilosofia.xlsx")
        display (filosofia_df)
    elif categoria == 4:
        suspense_df = pd.read_excel ("livrosSuspense.xlsx")
        display (suspense_df)
    elif categoria == 5:
        romance_df = pd.read_excel ("livrosRomance.xlsx")
        display (romance_df)
    input("Digite o nome do livro:")
    
    
    
elif opcao == 2:
    print("Aparece as reservas")
    #opcao 1=visualizar reservas 
    #opcao 2= fazer reserva
    
elif opcao == 3:
    print("Aparece o registro dos alunos")
    
elif opcao == 4:
    print("Aparece as entregas")

elif opcao == 5: #opcao para fazer a adicao de livros novos nas tabelas de cada categoria
    def categorias(lista):
        cabeçalho('CATEGORIAS')
        c=1
        for item in lista:
            print(f'{c}-{item}')
            c +=1
        print (linha())
    categorias (['Matemática', 'Física', 'Filosofia', 'Suspense', 'Romance'])
    categoria = int(input("Qual é a categoria desejada?:"))
    if categoria == 1:
        matematica_df = pd.read_excel ("livrosMatematica.xlsx")
        titulo = input('titulo:')
        autor = input('autor: ')
        Idioma = input('Idioma')
        Qtd = int(input('Quantidade:'))
    
    matematica_df.loc[len(matematica_df)] = [titulo , autor,"Matemática", Idioma, Qtd]
    display(matematica_df)

        
elif opcao == 6:
    print("Volta para a tela de login")
    
else:
    print("Resultado inválido")
# Out:
#   File "<ipython-input-29-3b97f0c6236c>", line 94
#     elif opcao == 6:
#     ^
# SyntaxError: invalid syntax

# %%
index = int(input("index:"))
y = int(input("Quantidade de livros pegos:"))
matematica_df.iat [index,4] = matematica_df.iat[index,4]-[y]  #PARA RETIRAR OU COLOCAR A QUANTIDADE--- ENTREGA: SOMA----REGISTRO ALUNO:SUBTRAI
matematica_df
# Out:
# index:1
# Quantidade de livros pegos:2
#                                                Título  \
# 0   Análise de Erros de Métodos Discretos para Pro...
# 1                              Elementos de Geometria
# 2           Estágio supervisionado III - Ensino Médio
# 3                            Formulário de Matemática
# 4                               Matemática Financeira
# 5                    Matemática: Manual de Orientação
# 6   Cálculo volume I – Tradução da 8ª. Edição Nort...
# 7   Cálculo - vol. II: Volume 2 – Tradução da 8ª. ...
# 8      Ten British Mathematicians of the 19th Century
# 9             Representations on the Subject of Money
# 10                            A Primer of Quaternions
# 11             A Treatise on the Theory of Invariants
# 12  Raciocínio Lógico-Matemático - Fundamentos e M...
# 13  Veja Matemática Machado - Volume único - Ensin...
# 14           Cálculo Diferencial e Integral: Volume 2
# 15           Cálculo Diferencial e Integral: Volume 1
# 16        Geometria Analítica: Um Tratamento Vetorial
# 17                      Álgebra Linear com Aplicações
# 18        Geometria Analítica: Um Tratamento Vetorial
# 19               Álgebra Linear e Geometria Analítica
#
#                                                 Autor   Categoria     Idioma  \
# 0                          Greice da Silva Lorenzzett  Matemática  Português
# 1                                            Euclides  Matemática  Português
# 2                                     Roberto Pettres  Matemática  Português
# 3                                     Roberto Pettres  Matemática  Português
# 4                                     Roberto Pettres  Matemática  Português
# 5                              Ministério da Educação  Matemática  Português
# 6                                       James Stewart  Matemática  Português
# 7                                       James Stewart  Matemática  Português
# 8                                Alexander Macfarlane  Matemática     Inglês
# 9                                        Isaac Newton  Matemática     Inglês
# 10                                 Arthur S. Hathaway  Matemática     Inglês
# 11                                    Oliver E. Glenn  Matemática     Inglês
# 12                                    Josimar Padilha  Matemática  Português
# 13                         Antonio dos Santos Machado  Matemática  Português
# 14                      Paulo Boulos e Zara Issa Abud  Matemática  Português
# 15                                      Paulo Boulos   Matemática  Português
# 16                     Ivan de Camargo e Paulo Boulos  Matemática  Português
# 17                                       Howard Anton  Matemática  Português
# 18  Fabiano José dos Santos e Silvimar Fábio Ferreira  Matemática  Português
# 19                                  Carla M. A. Pinto  Matemática  Português
#
#     Quantidade
# 0           15
# 1            9
# 2            9
# 3           21
# 4           12
# 5           10
# 6           21
# 7           11
# 8           17
# 9           15
# 10          18
# 11          20
# 12           8
# 13           5
# 14          14
# 15          25
# 16          22
# 17          21
# 18          23
# 19          27

# %%
x = input("Nome do livro:")
matematica_df[matematica_df["Título"].str.contains(pat=x,case=False)] #buscador, ele funciona com letras maiusculas, minusculas e partes de uma palavra, mas é necessário colocar os acentos
# Out:
# Nome do livro:cál
#                                                Título  \
# 6   Cálculo volume I – Tradução da 8ª. Edição Nort...
# 7   Cálculo - vol. II: Volume 2 – Tradução da 8ª. ...
# 14           Cálculo Diferencial e Integral: Volume 2
# 15           Cálculo Diferencial e Integral: Volume 1
#
#                             Autor   Categoria     Idioma  Quantidade
# 6                   James Stewart  Matemática  Português          21
# 7                   James Stewart  Matemática  Português          11
# 14  Paulo Boulos e Zara Issa Abud  Matemática  Português          14
# 15                  Paulo Boulos   Matemática  Português          25
